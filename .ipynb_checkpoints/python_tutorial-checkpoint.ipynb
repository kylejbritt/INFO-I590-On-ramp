# %% [markdown]
# #Install Python environment

# %% [markdown]
# 1. We recommend <a href="https://www.continuum.io/downloads">Anaconda</a> distribution for beginners. It has distribution for all platforms
#
# 2. For those already familiar with `Python`, you are free to use your already environment.
#
# 3. As for the version. `Python` 2.7 is recommended.(`Python` 3.X is not backward compatible)

# %% [markdown]
# # Running Python in terminal

# %% [markdown]
# After installing `Python` on your system successfully, you can start the interactive Python prompt by typing `python` in the command line and pressing `Enter`. It will show you some context information about Python similar to this:

# %%
# just ignore this code block.
from IPython.core.display import Image
Image(filename='files/1.jpg')

# %% [markdown]
# ##### For Window Users
# * On `windows`, you can start `Python` default interpreter throuth the `Start` Menu.
# * To exit `Python`, just press `Ctrl-D` in your terminal.
# * To run a `Python` script, type the following command in your terminal:

# %% [markdown]
# ```bash
# $ python your-python-script.py
# ```

# %% [markdown]
# # IPython notebook

# %% [markdown]
# Below, we are going to learn `Python` basics in `IPython` notebook. `Ipython` is built upon `Python` and it is an alternative to `Python`'s default interative shell. `Ipython` is a more powerful interactive computational environment that allow you to combine code execution, rich text and  math formula together right in your web browser!
#
# It also enables you to see the result of execution for each code block(code blocks are those cells with some green highlighted keywords).
#
# > Be noted that, you can also excute all the following `Python` code in `Python`'s default interpreter (But we encourage you to use ipython)
#
# Now, you can issue the following code in your terminal and let's get started playing Python within `IPython`! You can press `Ctrl+C` to shutdown `IPython` at any time.

# %% [markdown]
# ```bash
# $ ipython notebook
# ```

# %% [markdown]
# ####Some keyboard shortcuts for `Ipython` notebook
#
# > NOTE: To use these shortcuts for a code block, you should first double click into that block.
#
# * Basic operation:
#     1. control+return
#         To excute the current code block and stay in the same block.
#     2. shift+return
#         To excute the current code block and select the next block.
#         The result will be displayed directly below this block.
#
# * Instructions:
#     3. Please note that Only those blocks which begin with "In [ ]" are code blocks.
#     4. You are encouraged to modify and excute all the code blocks to have a try.
#     5. Google is always your best friends when coming with problems.
#
#     6. It is optional to do the exercise you encounter in this tutorial, except those we
#        explicitly syas "this exercise will be graded".
#     7. When doing the exercise, you can press "insert below" under "insert" tab in your web
#        browser and write your code in the new block you created and excute it to see the result using the above shortcuts.

# %% [markdown]
# #Variables

# %%
total = 0
for i in range(100):
    total = total + i
print total
print
# Out:
# 4950

# %%
can you modify the above code to calculate the sum of '1+3+5+...+999'?
clue: remove the '#' tag in the line below and excute this code block again.
# help(range)

# %%
# this defines a comment, which will be ignored by python interpreter. It makes your code more
# readable to others.
# a more efficient way
nums = range(100)
print sum(nums)
# Out:
# 4950

# %%
# a even more succinct way
print sum(range(100))
# Out:
# 4950

# %%
# integer and float
int_a = 20
float_b = 3.0
int_b = 3
print "I am int division", int_a/int_b
print "I am float division with more precise", int_a/float_b
# Out:
# I am int division 6
# I am float division with more precise 6.66666666667

# %% [markdown]
# #Loops

# %%
names = ['Alice', 'Bob', 'Hao']
for name in names:
    print name + ' is a bad guy'
# can you write up a funny loop on your own? it would be anything. Just have fun!
# Out:
# Alice is a bad guy
# Bob is a bad guy
# Hao is a bad guy

# %% [markdown]
# #Conditions

# %%
for n in names:
    if(n.startswith('H')):
        print n + ' is a good guy, I like it'
    else:
        print n + ' is a bad guy'
# Out:
# Alice is a bad guy
# Bob is a bad guy
# Hao is a good guy, I like it

# %% [markdown]
# #Functions

# %%
# define your own function using def as keywords.
def grade(score):
    level = ['A', 'B', 'C']
    if(score > 100):
        print "error! score greater than 100! Don't cheat!"
    # elif short for else if
    elif(score > 90):
        # the first element in a list is index from 1.
        print "your score is: ", score, ", you are in level: ", level[0]
    elif(score > 80):
        print "your score is: ", score, ", you are in level: ", level[1]
    else:
        print "your score is: ", score, ", you are in level: ", level[2]
    
# now call and test your function
grade(110)
grade(99)
grade(85)
grade(80)
# Out:
# error! score greater than 100! Don't cheat!
# your score is:  99 , you are in level:  A
# your score is:  85 , you are in level:  B
# your score is:  80 , you are in level:  C

# %% [markdown]
# Can you come up with a function to verify whether an integer is odd or even?

# %% [markdown]
# #String

# %%
line = "hello world!"
# inspect what's the type of this variable.
print type(line)
print line
count = 0
for char in line:
    # using a comma to print all char in a line.
    print char,
    count += 1
# after the loop, print a new line using charater '\n'.
print ' , this string has', count, 'characters, including space\n'
# reverse a string
print ''.join(reversed(line))
# more efficient way
print line[::-1]

# below is a block comment which allow you to comment on multiple lines.
'''
For any object that you don't know its available functions, You can get its type first by 
calling type() function like above. Then you can type [e.g. help(str)] in python interpreter.
It will display the usage of all build-in functions defined on that specific object.

Or, you can google it [e.g. 'python string']
'''
# Out:
# <type 'str'>
# hello world!
# h e l l o   w o r l d !  , this string has 12 characters, including space
#
# !dlrow olleh
# !dlrow olleh

# %% [markdown]
# #List

# %%
# declare a new list
line = "Today we are going to do some fun stuff with python python and python! we love it it"
my_list = []
for word in line.split():
    my_list.append(word)
print my_list
print
print 'There are',      len(my_list),           'words in my list\n'
# remove duplicates
my_set = set(my_list)
print my_set
print
print my_set.__contains__('python')
print 'python' in my_set
# Out:
# ['Today', 'we', 'are', 'going', 'to', 'do', 'some', 'fun', 'stuff', 'with', 'python', 'python', 'and', 'python!', 'we', 'love', 'it', 'it']
#
# There are 18 words in my list
#
# set(['and', 'do', 'we', 'stuff', 'love', 'python', 'python!', 'some', 'it', 'to', 'going', 'are', 'fun', 'with', 'Today'])
#
# True
# True

# %% [markdown]
# #Dict

# %%
# we can use backslash to display a string in multiple lines.
text = 'IPython is a command shell for interactive computing in multiple programming \
language , originally developed for the Python programming language, , that offers \
introspection, rich media, shell syntax, ! , tab completion, and history. IPython provides \
the following features. . .'

# each entry in python dict is a <key,value> pair, you can access the values through the keys.
word_freq = dict()
punctuations = [',', '.', '!', ';']
for word in text.split():
    # filter punctuations
    if(word not in punctuations):
        if(word not in word_freq):
            word_freq[word] = 1
        else:
            word_freq[word] += 1
print word_freq
# Out:
# {'and': 1, 'computing': 1, 'developed': 1, 'is': 1, 'tab': 1, 'in': 1, 'IPython': 2, 'for': 2, 'Python': 1, 'media,': 1, 'offers': 1, 'rich': 1, 'features.': 1, 'shell': 2, 'multiple': 1, 'provides': 1, 'that': 1, 'history.': 1, 'introspection,': 1, 'completion,': 1, 'a': 1, 'language': 1, 'originally': 1, 'programming': 2, 'language,': 1, 'syntax,': 1, 'command': 1, 'following': 1, 'the': 2, 'interactive': 1}

# %%
# Can you modify the function to give a 10% increase in everyone's salary using the dict below?
salary = {'Alice': 7000, 'Bob': 7543, 'Hao': 3457, 'Me': 9999, 'Boss': 10000}
def raise_salary(employee, your_dict):
    your_dict[employee] = your_dict[employee]
    print employee, 'has a salary of ', your_dict[employee]

for key,value in salary.items():
    raise_salary(key, salary)
# Out:
# Me has a salary of  9999
# Bob has a salary of  7543
# Boss has a salary of  10000
# Alice has a salary of  7000
# Hao has a salary of  3457

# %% [markdown]
# In the first dict example, we build a dict to compute the word frequence given a arbitrary sentence. However, you may find that it doen't work perfectly. e.g. it regard 'language,' and 'languare' as two different words.
#
# That's because our `str.split()` function splits a string from `space` character as default. Thus, 'language,' is regarded as a single word. Below is the correct way to do it.

# %%
# using build-in punctuations in string library
import string

text = 'IPython is a command shell for interactive computing in multiple programming \
language , originally developed for the Python programming language, , that offers \
introspection, rich media, shell syntax, ! , tab completion, and history. IPython provides \
the following features. . .'

exclude = set(string.punctuation)
clean_text = ''.join(char for char in text if char not in exclude)
print clean_text
# after that, we can use the same way to get word frequences of this text.
# Out:
# IPython is a command shell for interactive computing in multiple programming language  originally developed for the Python programming language  that offers introspection rich media shell syntax   tab completion and history IPython provides the following features

# %% [markdown]
# We can also use regular expression to filter the punctuations first.
# As we will see later, regular expression is a more powerful tool to match any sequence in any pattern. It is widely used for information extraction in web crawlers.

# %% [markdown]
# #Working with Text File and PNG File

# %%
# open accepts two arguments. 1st is file name you want to open, 2nd is 'r', 'w' or 'b'.
# 'r' means only read this file. 'w' means only write to this file. 'b' deals with binary file.
# 'r' and 'w' works for all text file. 'rb' and 'wb' words for say jpg, png, pdf files.

file = open('months.txt', 'r')
for line in file.readlines():
    # strip() removes new line character '\n'.
    print line.strip()
# don't forget to close the file
file.close()
# can you read this file and append each 'Month' into a list like ['January','May',...] ?
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
# urllib is a python build-in library to deal with network services.
import urllib
png_url = 'http://vignette4.wikia.nocookie.net/robber-penguin-agency/images/6/6e/\
Small-mario.png/revision/latest?cb=20150107080404'
# this is a png file, so use 'wb'.
png_file = open('me_on_ramp.png', 'wb')
binary_png = urllib.urlopen(png_url).read()
png_file.write(binary_png)
png_file.close()
# Take a look at what a funny pic you have get via Python! 
# It is located in the same dir with this IPython notebook.

# %% [markdown]
# #Regular expression in python

# %% [markdown]
# we highly encourage you to look at these references.
#
# http://www.tutorialspoint.com/python/python_reg_expressions.htm
#
# https://www.debuggex.com/cheatsheet/regex/python
#
# https://docs.python.org/2/library/re.html

# %%
A quick cheet sheet:
    
expression         match
    ^           match the begining position
    .           Any character except newline
    \w          one word character
    \W          one non-word character
    \d          one digit
    \D          one non-digit
    \s          one whitespace
    \S          one non-whitespace

# %%
Quantifiers    number to match
    *           0 or more
    +           1 or more
    ?           0 or 1
    {3,6}       Between 3 and 6
    {4}         exactly 4

# %%
# we must import regex library before we use it.
import re

text = 'IPython is a command shell for interactive computing in multiple programming \
language , originally developed for the Python programming language, , that offers \
introspection, rich media, shell syntax, ! , tab completion, and history. IPython provides \
the following features. . .'

# compile a regular expression you want to use, '\W+' means to match 1 or more non-word character.
# you can remove '+' to just use '\W'. What's your result then? Have a try!
pattern = re.compile('\W+')
clean_text = pattern.sub(' ', text)
print clean_text
print

def get_word_freq(text):
    for word in text.split():
        if(word not in word_freq):
            word_freq[word] = 1
        else:
            word_freq[word] += 1
    print word_freq

get_word_freq(clean_text)
# Out:
# IPython is a command shell for interactive computing in multiple programming language originally developed for the Python programming language that offers introspection rich media shell syntax tab completion and history IPython provides the following features
#
# {'and': 3, 'features': 2, 'computing': 3, 'developed': 3, 'is': 3, 'syntax': 2, 'tab': 3, 'in': 3, 'IPython': 6, 'completion': 2, 'for': 6, 'Python': 3, 'media': 2, 'media,': 1, 'introspection': 2, 'offers': 3, 'rich': 3, 'features.': 1, 'shell': 6, 'multiple': 3, 'provides': 3, 'that': 3, 'history.': 1, 'introspection,': 1, 'completion,': 1, 'a': 3, 'language': 5, 'originally': 3, 'programming': 6, 'language,': 1, 'syntax,': 1, 'command': 3, 'following': 3, 'the': 6, 'history': 2, 'interactive': 3}

# %%
# extract valid us phone numbers.
phones = ['812-349-8040', '0714-4798008', '020-23432134', '713-235-9809']
# begins with 3 digits, then '-', then 3 digits, then '-' and 4 digits at last.
pattern = re.compile('^\d{3}-\d{3}-\d{4}')
for phone in phones:
    found = pattern.search(phone)
    if found:
        print found.group()
# Out:
# 812-349-8040
# 713-235-9809

# %% [markdown]
# If you feel a little bit confusing, don't worry! Everyone starts from a newbie, as long as you
# try to understand the code and implement your own! Remember, practice always makes perfect.

# %% [markdown]
# # Grading Assignment

# %% [markdown]
# Are you ready to do some cool stuff using the tool box you learnt so far?
# Here is a webpage showing lots of adjective words:
# http://www.trussel.com/eding.htm
#
# Q : Can you extract all the adjective words ending with 'ing' (or all the 'ing' words) from the above webpage using regular expresion in `Python` (instead of manually copy and paste)?
#
# > This exercise is a pratice for you to use efficient tools to prepare and clean data from an arbitrary source.(In real world, data are always in a mess, and you need to extract it first)
#
# Clue :
#
# Before you figure out the right regular expression that works for this task, you should view your
# target webpage's html source code by right click your mouse in the browser and select 'view
# page source' (e.g. in chrome).
#
# The next step is to discover the regular patterns in which your target information shows up.
# Then, you can translate your observation of patterns into regular expressions which matches exactly the word you need.
#
# > Be noted that, there are often not only one feasible solutions for an this kind of tasks.

# %%
import urllib
import re

url = 'http://www.trussel.com/eding.htm'
htmlcode = urllib.urlopen(url).read()

# please first double click into this cell block and press 'shift + enter' to excute this block!
# you can print the html source code first and comment the line below after you figure it out.
print htmlcode
# put your code here
